# %% [markdown]
# # Matplotlib

# %% [markdown]
# For these exercises, we are using Pandas and Matplotlib to visualize Company Sales Data.
#
# We will be using the following dataset: https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv

# %% [markdown]
# ### Exercise 1: Read the Total profit of all months and show it using a line plot.
# Total profit data provided for each month. The enerated line plot must include the following properties:<br>
# - X label name = Month Number
# - Y label name = Total profit
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Write your code here
url = './company_sales_data.csv'

data = pd.read_csv(url)

# %%
df4 = pd.DataFrame(data)
df4.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# ### Exercise 2: Get the Total profit of all months and show a line plot with the following Style properties:
# - Line Style dotted and Line color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(10,8))
plt.plot(df4['month_number'], df4['total_profit'],linestyle = 'dashed', color = 'r', 
marker = 'o', mfc= 'black', linewidth = '3', label = 'total_profit',)
plt.xlabel('Month Number')
plt.ylabel('Sold units number')
plt.title('Company sales data of last year')
plt.legend(loc = 'lower right')

# %%
# Write your code here

# %% [markdown]
# ### Exercise 3: Read all product sales data and show it using a multiline plot.
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).
#
# The graph should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
plt.figure(figsize=(10,8))
plt.plot(df4['month_number'], df4['facewash'], label = "facewash Sales Data", marker = 'o', linewidth = 4)
plt.plot(df4['month_number'], df4['toothpaste'], label = "toothpaste Sales Data", marker = 'o', linewidth = 4)
plt.plot(df4['month_number'], df4['bathingsoap'], label = "bathingsoap Sales Data", marker = 'o', linewidth = 4)
plt.plot(df4['month_number'], df4['shampoo'], label = "shampoo Sales Data", marker = 'o', linewidth = 4)
plt.plot(df4['month_number'], df4['moisturizer'], label = "moisturizer Sales Data", marker ='o', linewidth = 4)
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.title('Sales Data')
plt.legend()
plt.show()

# %% [markdown]
# ### Exercise 4: Read the toothpaste sales data of each month and show it using a scatter plot.
# Also, add a grid in the plot (the grid line style should be “–“).
#
# The scatter plot should look like this:
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(12,8))
plt.scatter(df4['month_number'], df4['toothpaste'], s=150 )
plt.grid(True, color = 'grey', linewidth = 2,linestyle = '--')

# %% [markdown]
# ### Exercise 5: Read the face cream and facewash product sales data and show it using the bar chart.
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
fig, ax = plt.subplots(figsize = (10,8))
ax.bar([x-0.25 for x in df4['month_number'].tolist()],  df4['facecream'].tolist(), label = 'Faceream sales',width= 0.25, align='edge')
ax.bar([x+0.25 for x in df4['month_number'].tolist()],   df4['facewash'].tolist(), label = 'Facewash sales',width = -0.25, align='edge')
plt.xticks(df4['month_number'].tolist())
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.title('Facewash and Facecream Sales Data')
plt.legend(loc = 'upper left')
plt.grid(True, color = 'grey', linewidth = 2, linestyle ='--')

plt.show()

# %% [markdown]
# ### Exercise 6: Read the sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk.
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(10,8))
plt.bar(df4['month_number'], df4['bathingsoap'])
plt.grid(True, color = 'grey', linewidth =2, linestyle = '--')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.title('Bathing Soap Sales Data')
# Out:
# Text(0.5, 1.0, 'Bathing Soap Sales Data')

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges.
# The histogram should look like this:
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(10,8))
ranges = [150000, 175000, 200000, 225000, 250000, 300000, 350000]
plt.hist(df4['total_profit'], ranges)
plt.xlabel('profit range in dollars')
plt.ylabel('Actual profit in dollar')
plt.title('Profit Data')
plt.show()

# %% [markdown]
# ### Exercise 8: Calculate the total sale data for last year for each product and show it using a Pie chart.
# Note: In the Pie chart you should display the Number of units sold per year for each product in percentage.
#
# The Pie chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
charts = ['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer']
datas =  [df4['facecream'].sum(), df4['facewash'].sum(), df4['toothpaste'].sum(), 
         df4['bathingsoap'].sum(), df4['shampoo'].sum(), df4['moisturizer'].sum()]
plt.pie(datas, labels=charts, autopct='%1.1f%%') 
plt.title('Sales Data')
plt.legend(loc= 'lower right')   
plt.show()

# %% [markdown]
# ### Exercise 9: Read the Bathing soap facewash of all months and display it using the Subplot.
# The Subplot should look like this:
# ![image.png](attachment:image.png)

# %%
fig, ax = plt.subplots(2, sharex=True, figsize = (12,8))
ax[0].plot(df4['month_number'], df4['bathingsoap'], label = 'Bathingsoap Sales Data', color='k', marker='o', linewidth=3)
ax[0].set_title('Sales data of  a Bathingsoap')
ax[1].plot(df4['month_number'], df4['facewash'], label = 'Face Wash Sales Data', color='r', marker='o', linewidth=3)
ax[1].set_title('Sales data of  a facewash')

plt.xticks(df4['month_number'])
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.show()

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot.
# The Stack plot should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
plt.figure(figsize=(12,8))
plt.stackplot(df4['month_number'], df4['facecream'], df4['facewash'], df4['toothpaste'], df4['bathingsoap'],df4['shampoo'], df4['moisturizer'], colors = ['m','c','r','k','g','y'])
plt.plot([],[],color='m', label='face Cream', linewidth=5)
plt.plot([],[],color='c', label='Face wash', linewidth=5)
plt.plot([],[],color='r', label='Tooth paste', linewidth=5)
plt.plot([],[],color='k', label='Bathing soap', linewidth=5)
plt.plot([],[],color='g', label='Shampoo', linewidth=5)
plt.plot([],[],color='y', label='Moisturizer', linewidth=5)
plt.xlabel('Month Number')
plt.ylabel('Total Sales')
plt.title('all products sales')
plt.legend(loc='upper left')
plt.show()
