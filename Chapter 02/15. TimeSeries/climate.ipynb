# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_csv("climate.csv")
data = data.drop(["Date Time"], axis = 1)
data.head(8)
# Out:
#    p (armb)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 0    996.52     -8.02    265.40        -8.90    93.3          3.33
# 1    996.57     -8.41    265.01        -9.28    93.4          3.23
# 2    996.53     -8.51    264.91        -9.31    93.9          3.21
# 3    996.51     -8.31    265.12        -9.07    94.2          3.26
# 4    996.51     -8.27    265.15        -9.04    94.1          3.27
# 5    996.50     -8.05    265.38        -8.78    94.4          3.33
# 6    996.50     -6.62    265.81        -8.30    94.8          3.44
# 7    996.50     -7.62    265.81        -8.36    94.4          3.44
#
#    VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 0          3.11          0.22       1.94             3.12       1307.75
# 1          3.02          0.21       1.89             3.03       1309.80
# 2          3.01          0.20       1.88             3.02       1310.24
# 3          3.07          0.19       1.92             3.08       1309.19
# 4          3.08          0.19       1.92             3.09       1309.00
# 5          3.14          0.19       1.96             3.15       1307.86
# 6          3.26          0.18       2.04             3.27       1305.68
# 7          3.25          0.19       2.03             3.26       1305.69
#
#    wv (m/s)  max. wv (m/s)  wd (deg)
# 0      1.03           1.75     152.3
# 1      0.72           1.50     136.1
# 2      0.19           0.63     171.6
# 3      0.34           0.50     198.0
# 4      0.32           0.63     214.3
# 5      0.21           0.63     192.7
# 6      0.18           0.63     166.5
# 7      0.19           0.50     118.6

# %%
def pairing(data, seq_len=6):

    x = []
    y = []
        
    for i in range(0, data.shape[0]-(seq_len+1), seq_len+1):
 
        seq=np.zeros((seq_len, data.shape[1]))
        
        for j in range(seq_len):
            seq[j] = data.values[i+j]

        x.append(seq)    
        y.append(data['Tdew (degC)'][i+seq_len])        
    return np.array(x), np.array(y)
        
x,y=pairing(data)

# %%
print(x.shape)
print(y.shape)
# Out:
# (60078, 6, 14)
# (60078,)

# %%
print(y[0])
print(y[1])
# Out:
# -8.3
# -9.68

# %%
data.head(14)
# Out:
#     p (armb)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 0     996.52     -8.02    265.40        -8.90    93.3          3.33
# 1     996.57     -8.41    265.01        -9.28    93.4          3.23
# 2     996.53     -8.51    264.91        -9.31    93.9          3.21
# 3     996.51     -8.31    265.12        -9.07    94.2          3.26
# 4     996.51     -8.27    265.15        -9.04    94.1          3.27
# 5     996.50     -8.05    265.38        -8.78    94.4          3.33
# 6     996.50     -6.62    265.81        -8.30    94.8          3.44
# 7     996.50     -7.62    265.81        -8.36    94.4          3.44
# 8     996.50     -7.91    265.52        -8.73    93.8          3.36
# 9     996.53     -8.43    264.99        -9.34    93.1          3.23
# 10    996.62     -8.76    264.66        -9.66    93.1          3.14
# 11    996.62     -8.88    264.54        -9.77    93.2          3.12
# 12    996.63     -8.85    264.57        -9.70    93.5          3.12
# 13    996.74     -8.83    264.58        -9.68    93.5          3.13
#
#     VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 0           3.11          0.22       1.94             3.12       1307.75
# 1           3.02          0.21       1.89             3.03       1309.80
# 2           3.01          0.20       1.88             3.02       1310.24
# 3           3.07          0.19       1.92             3.08       1309.19
# 4           3.08          0.19       1.92             3.09       1309.00
# 5           3.14          0.19       1.96             3.15       1307.86
# 6           3.26          0.18       2.04             3.27       1305.68
# 7           3.25          0.19       2.03             3.26       1305.69
# 8           3.15          0.21       1.97             3.16       1307.17
# 9           3.00          0.22       1.88             3.02       1309.85
# 10          2.93          0.22       1.83             2.94       1311.64
# 11          2.90          0.21       1.81             2.91       1312.25
# 12          2.92          0.20       1.82             2.93       1312.11
# 13          2.92          0.20       1.83             2.93       1312.15
#
#     wv (m/s)  max. wv (m/s)  wd (deg)
# 0       1.03           1.75     152.3
# 1       0.72           1.50     136.1
# 2       0.19           0.63     171.6
# 3       0.34           0.50     198.0
# 4       0.32           0.63     214.3
# 5       0.21           0.63     192.7
# 6       0.18           0.63     166.5
# 7       0.19           0.50     118.6
# 8       0.28           0.75     188.5
# 9       0.59           0.88     185.0
# 10      0.45           0.88     183.2
# 11      0.25           0.63     190.3
# 12      0.16           0.50     158.3
# 13      0.36           0.63     184.8

# %%
group = []
for i in range(x.shape[0]):
    feat = []

    for j in range(x.shape[2]):
        feat.append(np.std(x.shape[i][:, j]))
        feat.append(x.shape[i][:, j][-1])
    group.append(feat)
print(group)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\asus\Documents\GitHub\strive_exer_ai_feb22\Chapter 02\15. TimeSeries\climate.ipynb Cell 7' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/asus/Documents/GitHub/strive_exer_ai_feb22/Chapter%2002/15.%20TimeSeries/climate.ipynb#ch0000016?line=2'>3</a> feat = []
#       <a href='vscode-notebook-cell:/c%3A/Users/asus/Documents/GitHub/strive_exer_ai_feb22/Chapter%2002/15.%20TimeSeries/climate.ipynb#ch0000016?line=4'>5</a> for j in range(x.shape[2]):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/asus/Documents/GitHub/strive_exer_ai_feb22/Chapter%2002/15.%20TimeSeries/climate.ipynb#ch0000016?line=5'>6</a>     feat.append(np.std(x.shape[i][:, j]))
#       <a href='vscode-notebook-cell:/c%3A/Users/asus/Documents/GitHub/strive_exer_ai_feb22/Chapter%2002/15.%20TimeSeries/climate.ipynb#ch0000016?line=6'>7</a>     feat.append(x.shape[i][:, j][-1])
#       <a href='vscode-notebook-cell:/c%3A/Users/asus/Documents/GitHub/strive_exer_ai_feb22/Chapter%2002/15.%20TimeSeries/climate.ipynb#ch0000016?line=7'>8</a> group.append(feat)
#
# TypeError: 'int' object is not subscriptable

# %%
def new_features(data):

    
    new_data = []
    
    for i in range(data.shape[0]):

        group = []   
    
        for j in range(data.shape[2]):

            group.append(np.std(data[i][:, j]))  
            group.append(np.mean(data[i][:, j]))
            group.append(np.median(data[i][:, j]))
            group.append(data[i][:, j][-1])     

        new_data.append(group)
    return np.array(new_data)
    
        

x = new_features(x)

# %%
data.shape
# Out:
# (420551, 14)

# %%
for i in range(data.shape[0]):
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\asus\Documents\GitHub\strive_exer_ai_feb22\Chapter 02\15. TimeSeries\climate.ipynb Cell 8' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/asus/Documents/GitHub/strive_exer_ai_feb22/Chapter%2002/15.%20TimeSeries/climate.ipynb#ch0000014?line=0'>1</a> for i in range(data.shape[0]):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/asus/Documents/GitHub/strive_exer_ai_feb22/Chapter%2002/15.%20TimeSeries/climate.ipynb#ch0000014?line=2'>3</a>     for j in range(data.shape[2]):
#       <a href='vscode-notebook-cell:/c%3A/Users/asus/Documents/GitHub/strive_exer_ai_feb22/Chapter%2002/15.%20TimeSeries/climate.ipynb#ch0000014?line=3'>4</a>         print(j)
#
# IndexError: tuple index out of range

# %%
x
# Out:
# array([[2.28521820e-02, 9.96523333e+02, 9.96515000e+02, ...,
#         1.77500000e+02, 1.82150000e+02, 1.92700000e+02],
#        [5.76387216e-02, 9.96566667e+02, 9.96575000e+02, ...,
#         1.70650000e+02, 1.84100000e+02, 1.58300000e+02],
#        [5.41602560e-02, 9.96860000e+02, 9.96850000e+02, ...,
#         1.76550000e+02, 1.61550000e+02, 1.15300000e+02],
#        ...,
#        [5.37483850e-02, 1.00144667e+03, 1.00143500e+03, ...,
#         2.05300000e+02, 2.01000000e+02, 1.88100000e+02],
#        [1.50738921e-01, 1.00106333e+03, 1.00104500e+03, ...,
#         9.83666667e+01, 9.19900000e+01, 9.40000000e+00],
#        [1.38924440e-01, 1.00043000e+03, 1.00044500e+03, ...,
#         2.03883333e+02, 2.03500000e+02, 2.23700000e+02]])

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train.shape
# Out:
# (48062, 56)

# %%
y_train.shape
# Out:
# (48062,)

# %%
model = RandomForestRegressor()
model.fit(x_train,y_train)
pred = model.predict(x_test)

# %%
scores = cross_val_score(model, x_train,y_train, cv = 3)
scores
# Out:
# array([0.99911819, 0.99911712, 0.99916048])
